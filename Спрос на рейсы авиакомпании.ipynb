# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
data_1 = pd.read_csv('C://Users//Igor//Desktop//data_analyst//4 project//query_1.csv')
data_3 = pd.read_csv('C://Users//Igor//Desktop//data_analyst//4 project//query_3.csv')

# %% [markdown]
# ### 1. Проверим типы данных на корректность

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   model           8 non-null      object
#  1   flights_amount  8 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 256.0+ bytes

# %%
data_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   city             101 non-null    object
#  1   average_flights  101 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 1.7+ KB

# %% [markdown]
# ### 2. Выберем топ-10 городов по количеству рейсов

# %%
data_3 = data_3.sort_values(by='average_flights', ascending=False)
top10 = data_3.head(10)
top10
# Out:
#                city  average_flights
# 43           Москва       129.774194
# 70  Санкт-Петербург        31.161290
# 54      Новосибирск        17.322581
# 33       Красноярск        11.580645
# 20     Екатеринбург        11.322581
# 67   Ростов-на-Дону        10.193548
# 63            Пермь        10.129032
# 10           Брянск        10.000000
# 74             Сочи         9.612903
# 84        Ульяновск         9.580645

# %% [markdown]
# ### 3. Построим графики: модели самолетов и количество рейсов, города и количество рейсов, топ-10 городов и количество рейсов

# %% [markdown]
# #### 3.1 Модели самолетов

# %%
data_1.plot(x = 'model', y='flights_amount', kind = 'bar')
print('Количество полетов для самолетов разных моделей')
# Out:
# Количество полетов для самолетов разных моделей

# %%
data_3.plot(x = 'city', y='average_flights', kind = 'bar', figsize=(20,10))
print('Количество полетов для всех городов')
# Out:
# Количество полетов для всех городов

# %%
top10.plot(x = 'city', y='average_flights', kind = 'bar', figsize=(10,5))
print('Количество полетов для топ 10 городов')
# Out:
# Количество полетов для топ 10 городов
